# %% [markdown]
# # Линейные модели и нейронные сети. Практическая работа

# %% [markdown]
# В этой практической работе пять обязательных задач.
#
# Они помогут понять, что вы действительно усвоили материал модуля.
#
# Удачи!

# %% [markdown]
# ## Цели практической работы
# Потренироваться в обучении модели:
# - линейной регрессии;
# - логистической регрессии;
# - многослойного персептрона.

# %% [markdown]
# ## Что входит в практическую работу
#
# 1. Загрузите датасет и ознакомьтесь с ним.
# 2. Обучите линейную регрессию, включая признаки с нулевым весом и без них. Замерьте качество.
# 3. Обучите случайный лес. Замерьте качество.
# 4. Обучите многослойный перцептрон. Замерьте качество.
# 5. Реализуйте стратегию голосования. Замерьте качество.

# %% [markdown]
# ## Что оценивается
#
# * Выполнены все задания. В каждом:
#  * в коде нет ручных перечислений, все действия автоматизированы;
#  * результаты вычислений и применённых операций корректны;
#  * ответы на вопросы, где требуется, корректны и обоснованы;
#  * код читабелен: переменным даны осмысленные названия, соблюдены отступы и правила расстановки пробелов. Стилизация кода соответствует рекомендациям [PEP 8](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html).
#
# * Репозиторий проекта оформлен корректно:
#  * содержит осмысленные коммиты, содержащие конкретные реализованные фичи;
#  * ветки названы согласно назначению;
#  * файлы, не связанные с проектом, не хранятся в репозитории.

# %% [markdown]
# ## Как отправить работу на проверку
#
# Сдайте практическую работу этого модуля через систему контроля версий Git сервиса Skillbox GitLab. После загрузки работы на проверку напишите об этом в личном кабинете своему куратору.

# %% [markdown]
# ## Задача
#
# Постройте модель классификации, определяющую категорию цены / цену подержанного автомобиля в зависимости от характеристик транспортного средства.
#
# Используйте датасет из коллекции подержанных автомобилей, выставленных на продажу в Соединенных Штатах. Он уже подготовлен, без выбросов и с категориальными фичами, преобразованными с помощью one hot encoding, и количественными фичами, стандартизированными с помощью скейлеров.

# %% [markdown]
# ### Описание датасета:
# - `id`— идентификатор записи;
# - `is_manufacturer_name`— признак производителя автомобиля;
#
# - `region_*`— регион;
# - `x0_*`— тип топлива;
# - `manufacturer_*`— производитель;
# - `short_model_*`— сокращённая модель автомобиля;
# - `title_status_*`— статус;
# - `transmission_*`— коробка передач;
# - `state_*`— штат;
# - `age_category_*`— возрастная категория автомобиля;
#
# - `std_scaled_odometer`— количество пройденных миль (после стандартизации);
# - `year_std`— год выпуска (после стандартизации);
# - `lat_std`— широта (после стандартизации);
# - `long_std`— долгота (после стандартизации);
# - `odometer/price_std`— отношение стоимости к пробегу автомобиля (после стандартизации);
# - `desc_len_std`— количество символов в тексте объявления о продаже (после стандартизации);
# - `model_in_desc_std`— количество наименований модели автомобиля в тексте объявления о продаже (после стандартизации);
# - `model_len_std`— длина наименования автомобиля (после стандартизации);
# - `model_word_count_std`— количество слов в наименовании автомобиля (после стандартизации);
# - `month_std`— номер месяца размещения объявления о продаже автомобиля (после стандартизации);
# - `dayofweek_std`— день недели размещения объявления о продаже автомобиля (после стандартизации);
# - `diff_years_std`— количество лет между годом производства автомобиля и годом размещения объявления о продаже автомобиля (после стандартизации);
# - `price`— стоимость;
# - `price_category`— категория цены.

# %% [markdown]
# ## Обязательные задачи

# %%
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix, mean_absolute_error
from sklearn.model_selection import train_test_split 
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from statistics import mode

# %%
df = pd.read_csv('vehicles_dataset_prepared.csv')
df.head()
# Out:
#            id  price price_category  is_audi  is_ford  is_chevrolet  \
# 0  7308295377  54990           high        0        0             0
# 1  7316380095  16942         medium        0        1             0
# 2  7313733749  35590           high        0        0             0
# 3  7308210929  14500         medium        0        0             0
# 4  7303797340  14590         medium        0        0             0
#
#    is_toyota  x0_diesel  x0_electric  x0_gas  ...  long_std  year_std  \
# 0          0        1.0          0.0     0.0  ...  0.484245  1.322394
# 1          0        0.0          0.0     0.0  ...  1.110800  0.695973
# 2          0        0.0          0.0     1.0  ...  0.531185  0.852578
# 3          1        0.0          0.0     1.0  ...  0.853562  0.226157
# 4          0        0.0          0.0     0.0  ...  0.557607  0.069552
#
#    odometer/price_std  desc_len_std  model_in_desc_std  model_len_std  \
# 0           -0.510784      0.632075          -0.155788       1.163032
# 1           -0.402947     -0.646781          -0.155788       0.932087
# 2           -0.514480      0.560744          -0.155788       0.470197
# 3           -0.241883      0.180435          -0.155788      -0.915473
# 4           -0.333074      0.766366          -0.155788       1.163032
#
#    model_word_count_std  month_std  dayofweek_std  diff_years_std
# 0              1.910669  -0.615846       1.120284       -1.322394
# 1              1.235799   1.623784      -1.374972       -0.695973
# 2              0.560930  -0.615846      -0.376870       -0.852578
# 3             -0.788810  -0.615846       1.120284       -0.226157
# 4              1.910669  -0.615846       0.122182       -0.069552
#
# [5 rows x 1463 columns]

# %% [markdown]
# **Задача 1. Линейная регрессия**
#
# Вспомните задачу по предсказанию стоимости подержанного автомобиля. Попробуйте обучить модель линейной регрессии для предсказания цены автомобиля (колонка `price`). Для этого сделайте шаги:
#
# - подготовьте данные: удалите колонки, которые косвенно содержат информацию о целевой переменной (`odometer/price_std`, `price_category`);
# - разделите выборку на треин и тест в отношении 70/30;
# - обучите модель линейной регрессии с дефолтными параметрами;
# - посчитайте значение метрики mae на тестовой выборке для линейной регрессии;
# - выведите получившиеся коэффициенты линейной регрессии при каждом параметре обучающей выборки с помощью метода `coef_` (есть ли коэффициенты, которые равны нулю? Если есть, выведите названия фичей с нулевым коэффициентом);
# - удалите фичи, коэффициенты которых равны нулю; переобучите модель; убедитесь, что значение метрики не изменилось.

# %%
new_df = df.copy()
new_df = new_df.drop(columns=['odometer/price_std', 'price_category'])
new_df.describe()
# Out:
#                  id         price      is_audi      is_ford  is_chevrolet  \
# count  9.619000e+03   9619.000000  9619.000000  9619.000000   9619.000000
# mean   7.311568e+09  18014.652771     0.020064     0.162283      0.128808
# std    4.358556e+06  12498.618213     0.140228     0.368729      0.335004
# min    7.301586e+09    500.000000     0.000000     0.000000      0.000000
# 25%    7.308208e+09   7500.000000     0.000000     0.000000      0.000000
# 50%    7.312785e+09  15000.000000     0.000000     0.000000      0.000000
# 75%    7.315287e+09  26990.000000     0.000000     0.000000      0.000000
# max    7.317090e+09  57999.000000     1.000000     1.000000      1.000000
#
#          is_toyota    x0_diesel  x0_electric       x0_gas    x0_hybrid  ...  \
# count  9619.000000  9619.000000  9619.000000  9619.000000  9619.000000  ...
# mean      0.079426     0.058010     0.004470     0.850296     0.010708  ...
# std       0.270417     0.233775     0.066714     0.356799     0.102929  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000     1.000000     0.000000  ...
# 50%       0.000000     0.000000     0.000000     1.000000     0.000000  ...
# 75%       0.000000     0.000000     0.000000     1.000000     0.000000  ...
# max       1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#             lat_std      long_std      year_std  desc_len_std  \
# count  9.619000e+03  9.619000e+03  9.619000e+03  9.619000e+03
# mean   2.068323e-16 -4.498602e-16  9.365070e-15 -2.419199e-17
# std    1.000052e+00  1.000052e+00  1.000052e+00  1.000052e+00
# min   -3.331829e+00 -3.593801e+00 -2.592738e+00 -9.976116e-01
# 25%   -6.436450e-01 -7.306875e-01 -5.568694e-01 -8.161916e-01
# 50%    1.219966e-01  3.388739e-01  2.261569e-01 -2.169780e-01
# 75%    6.607601e-01  7.402470e-01  8.525780e-01  5.421837e-01
# max    4.605283e+00  1.053179e+01  1.322394e+00  8.745933e+00
#
#        model_in_desc_std  model_len_std  model_word_count_std     month_std  \
# count       9.619000e+03   9.619000e+03          9.619000e+03  9.619000e+03
# mean        3.619565e-17  -4.838398e-17          2.289929e-17 -1.477373e-16
# std         1.000052e+00   1.000052e+00          1.000052e+00  1.000052e+00
# min        -1.557884e-01  -1.261890e+00         -7.888096e-01 -6.158456e-01
# 25%        -1.557884e-01  -6.845279e-01         -7.888096e-01 -6.158456e-01
# 50%        -1.557884e-01  -3.381103e-01         -1.139399e-01 -6.158456e-01
# 75%        -1.557884e-01   5.856698e-01          5.609297e-01  1.623784e+00
# max         2.640041e+01   2.021600e+01          1.810754e+01  1.623784e+00
#
#        dayofweek_std  diff_years_std
# count   9.619000e+03    9.619000e+03
# mean   -9.750664e-17    9.898402e-17
# std     1.000052e+00    1.000052e+00
# min    -1.374972e+00   -1.322394e+00
# 25%    -8.759208e-01   -8.525780e-01
# 50%     1.221817e-01   -2.261569e-01
# 75%     6.212330e-01    5.568694e-01
# max     1.619336e+00    2.592738e+00
#
# [8 rows x 1461 columns]

# %%
train, test = train_test_split(new_df, test_size=0.3, random_state=42)

lr = LinearRegression()
lr.fit(train.drop(columns=['price']), train.price)
pred = lr.predict(test.drop(columns=['price']))
mean_absolute_error(test.price, pred)
# Out:
# 4600.341115694433

# %%
for col, i in zip(train.drop(columns=['price']), lr.coef_):
    print(f'Колонка: {col}   {i}')
# Out:
# Колонка: id   6.359510288389939e-06
# Колонка: is_audi   254.2981661927265
# Колонка: is_ford   1073.9077037503357
# Колонка: is_chevrolet   -184.7628323244553
# Колонка: is_toyota   471.49761621540017
# Колонка: x0_diesel   5848.605892491521
# Колонка: x0_electric   -2828.8711067383083
# Колонка: x0_gas   -1494.5893095636688
# Колонка: x0_hybrid   -780.5412627087799
# Колонка: x0_other   -744.6087182533597
# Колонка: std_scaled_odometer   -3529.656754955038
# Колонка: short_model_-benz   -5706.119266522651
# Колонка: short_model_1   -7089.737600451979
# Колонка: short_model_124   -0.00043907992403546814
# Колонка: short_model_128i   -8435.624925817983
# Колонка: short_model_135i   -4437.962431444916
# Колонка: short_model_1500   -499.6192941300137
# Колонка: short_model_163869   301.88350646663093
# Колонка: short_model_1928   -0.0003358977032803523
# Колонка: short_model_1951   11515.895011136952
# Колонка: short_model_1954   2447.6969132496674
# Колонка: short_model_1960s   -3561.6815890415164
# Колонка: short_model_1966   41204.78807268239
# Колонка: short_model_1968   22801.39404349729
# Колонка: short_model_1972   11668.665051572241
# Колонка: short_model_1977   -0.0003919281134585617
# Колонка: short_model_1978   6010.053129917439
# Колонка: short_model_198.5   11293.534897431833
# Колонка: short_model_1988   -1178.4200334464476
# Колонка: short_model_1994   -5158.609788904538
# Колонка: short_model_1999   -0.000364913709290704
# Колонка: short_model_2   -3652.4240477849003
# Колонка: short_model_200   -2946.9342236231964
# Колонка: short_model_2000   0.00011308189914416289
# Колонка: short_model_2002   6654.1782235039755
# Колонка: short_model_2006   0.00011266413048360846
# Колонка: short_model_2007   -3383.6752476059924
# Колонка: short_model_2008   -4260.465597211286
# Колонка: short_model_2009   -2360.7348318815884
# Колонка: short_model_2012   14411.895594716663
# Колонка: short_model_2015   0.00018351605513089453
# Колонка: short_model_2016   -0.0002570220726880734
# Колонка: short_model_2017   23933.048660015345
# Колонка: short_model_2018   14103.21914456514
# Колонка: short_model_210   -0.00019887225698766997
# Колонка: short_model_240   3137.0973611389004
# Колонка: short_model_2500   4787.373120908462
# Колонка: short_model_2500hd   0.00024299948245243286
# Колонка: short_model_280zx   5636.789305446706
# Колонка: short_model_3   -4523.933113543492
# Колонка: short_model_3-series   -3587.72536038424
# Колонка: short_model_3-window   0.0006546054218574682
# Колонка: short_model_3.2   -2647.1663627946723
# Колонка: short_model_300   2184.335265944948
# Колонка: short_model_300-series   3926.477236008138
# Колонка: short_model_300c   4440.293625822575
# Колонка: short_model_300s   5893.805531164641
# Колонка: short_model_300zx   5903.034872224659
# Колонка: short_model_3100   16380.774974738031
# Колонка: short_model_318i   3845.8695435949126
# Колонка: short_model_320i   -9248.546444704794
# Колонка: short_model_323i   -0.0001951309332071105
# Колонка: short_model_325ci   -4058.4437518964774
# Колонка: short_model_325i   -4779.51079903295
# Колонка: short_model_325is   26479.159626621473
# Колонка: short_model_325xi   -4442.37272656802
# Колонка: short_model_328   -5259.18017668767
# Колонка: short_model_328ci   -0.00032024869801716704
# Колонка: short_model_328d   -17957.78603412418
# Колонка: short_model_328i   -8989.659336628189
# Колонка: short_model_328xi   -8492.476656834377
# Колонка: short_model_330i   -3077.1097275147995
# Колонка: short_model_330xi   -7671.093977923397
# Колонка: short_model_335i   -15918.041405813852
# Колонка: short_model_335xi   -6624.883123262368
# Колонка: short_model_350   -3898.8417277338203
# Колонка: short_model_3500   6083.919278501876
# Колонка: short_model_3500hd   4143.826602767609
# Колонка: short_model_350z   -6531.809777009946
# Колонка: short_model_370z   4123.02947735728
# Колонка: short_model_380sl   14840.96908077615
# Колонка: short_model_3i   -5100.61728780949
# Колонка: short_model_4   -836.7726423262147
# Колонка: short_model_4-runner   21633.001159120395
# Колонка: short_model_428   -574.9016065791393
# Колонка: short_model_430i   920.9551192205853
# Колонка: short_model_435i   -6594.70809016174
# Колонка: short_model_440xi   0.00028509908088381053
# Колонка: short_model_4500   12740.735946609115
# Колонка: short_model_4runner   4676.260671244672
# Колонка: short_model_4x4   21276.07032220833
# Колонка: short_model_5   -5371.613542403285
# Колонка: short_model_5-series   -9766.265682520705
# Колонка: short_model_50   5.975867225060938e-05
# Колонка: short_model_500   -3984.4190455698063
# Колонка: short_model_500c   3017.2537164541977
# Колонка: short_model_500l   -8059.829813372787
# Колонка: short_model_500x   0.00020022058379254304
# Колонка: short_model_525i   -0.00011732025126320877
# Колонка: short_model_528i   -6191.471932573939
# Колонка: short_model_528xi   -7515.351247031718
# Колонка: short_model_530   -7223.251076641048
# Колонка: short_model_530i   -8.256630917458097e-05
# Колонка: short_model_535i   -6139.836238056756
# Колонка: short_model_535xi   -0.000434827992648934
# Колонка: short_model_540i   -1582.7578146970648
# Колонка: short_model_545i   -0.00015291775942927188
# Колонка: short_model_5500   14675.436204226422
# Колонка: short_model_5500hd   3593.356286106777
# Колонка: short_model_550i   -8763.747217264245
# Колонка: short_model_5th   12099.889943564147
# Колонка: short_model_6   8562.9757806165
# Колонка: short_model_640   -0.00016386142306146212
# Колонка: short_model_645ci   -1819.0635287666787
# Колонка: short_model_650i   -4790.306068384012
# Колонка: short_model_650xi   2.052296383681096e-05
# Колонка: short_model_7   1129.7735350568296
# Колонка: short_model_750   -3552.745694585098
# Колонка: short_model_750i   2.5643544177000877e-05
# Колонка: short_model_750xi   -367.81074543710974
# Колонка: short_model_86   -3239.4283695474815
# Колонка: short_model_911   -3333.333462508811
# Колонка: short_model_914   -19629.443948223285
# Колонка: short_model_928   -6666.653531555246
# Колонка: short_model_944   0.0003291267894383054
# Колонка: short_model_ACURA*   -2207.165210981487
# Колонка: short_model_ALL   -22482.050887635447
# Колонка: short_model_AM   11246.200402439943
# Колонка: short_model_AMC   4268.163764182327
# Колонка: short_model_ASC   9266.418747948537
# Колонка: short_model_Acuarea   0.00031603749357600464
# Колонка: short_model_American   1289.8776768906662
# Колонка: short_model_BUY   -24883.653042390924
# Колонка: short_model_Bentley   -0.00018358539091423154
# Колонка: short_model_Blue   9285.351780131474
# Колонка: short_model_Buicks   -506.299528825004
# Колонка: short_model_C   -655.0356484952398
# Колонка: short_model_CHEVORLET   -10010.931659810316
# Колонка: short_model_CLICK   -29098.23745398854
# Колонка: short_model_Champion   0.00014947064300940838
# Колонка: short_model_Chevey   -12671.618246599428
# Колонка: short_model_Chevorlet   34627.883642148394
# Колонка: short_model_Comanche   6254.395306488604
# Колонка: short_model_Comet   -2919.728919038361
# Колонка: short_model_D7FH173552   26818.678069232716
# Колонка: short_model_DODGE1500   4412.125502598158
# Колонка: short_model_Diahatsu   -1728.5787977914708
# Колонка: short_model_E46   -2381.4341228934677
# Колонка: short_model_EASY   -5049.726286877927
# Колонка: short_model_Eagle   2335.6018170073207
# Колонка: short_model_Emergency   8483.9112112191
# Колонка: short_model_F-250   413.85412151325033
# Колонка: short_model_F250   3665.800683408289
# Колонка: short_model_FORD*   -0.000285384051494475
# Колонка: short_model_FORD/RANGER   -3549.958059914996
# Колонка: short_model_FREIGHTLINER   7870.616787405449
# Колонка: short_model_FRRV   -14856.241127933745
# Колонка: short_model_Flexible   -29838.589283832192
# Колонка: short_model_FordE350   -5.7611518968769815e-06
# Колонка: short_model_Freightliner   14657.130991294991
# Колонка: short_model_Frtlner   -5.970642041575047e-05
# Колонка: short_model_GCM   0.0003699787066580029
# Колонка: short_model_GEHL   0.000174599583260715
# Колонка: short_model_GMC,   3446.48907097791
# Колонка: short_model_GMX   -0.0003535214209477999
# Колонка: short_model_GRAND   0.0003120708346386891
# Колонка: short_model_GULF   8.834986556394142e-05
# Колонка: short_model_Genesis   -777.8346236055368
# Колонка: short_model_Gx   10895.344317740522
# Колонка: short_model_HINO   6924.056866467022
# Колонка: short_model_HUMMER   5277.978889743039
# Колонка: short_model_Hino   0.00011830392895717523
# Колонка: short_model_Hobda   1.2110155694244895e-05
# Колонка: short_model_Hot   13412.865771666975
# Колонка: short_model_Hummer   10966.264830995122
# Колонка: short_model_IC   -11658.752934467182
# Колонка: short_model_INTERNATIONAL   -0.00019118632553727366
# Колонка: short_model_International   4678.036181616594
# Колонка: short_model_Isizu   -7153.206773462872
# Колонка: short_model_Isuzu   9836.998319137127
# Колонка: short_model_JM1BK32F871604924   -3075.7404670360047
# Колонка: short_model_Janesville   -0.00014734032811247744
# Колонка: short_model_Jauguar   0.00011317282405798323
# Колонка: short_model_Jayco   -0.0001657702050579246
# Колонка: short_model_Kaiser   -4268.737469266738
# Колонка: short_model_Lotus   33427.02620897394
# Колонка: short_model_MASERATI   4096.971890891535
# Колонка: short_model_MERCUTY   -9245.623406983439
# Колонка: short_model_MERDECES   -4.0468808947480284e-05
# Колонка: short_model_MGB   6895.297658725368
# Колонка: short_model_MITUSBISHI   0.00013621742618852295
# Колонка: short_model_MV-1   -3.428296622587368e-06
# Колонка: short_model_Maserati   13354.272605540933
# Колонка: short_model_Minin   -0.00023645986220799387
# Колонка: short_model_Nascar   -3926.545851336338
# Колонка: short_model_OLDSMOBILE   0.00011790315693360753
# Колонка: short_model_PLYMOUTH   48653.75339507042
# Колонка: short_model_PROGRAMS   -19528.64252388425
# Колонка: short_model_Peterbilt   57474.827976188964
# Колонка: short_model_Pierce   9096.541806338399
# Колонка: short_model_Plymouth   18809.805164982085
# Колонка: short_model_QX   3885.1370813155504
# Колонка: short_model_S60   -5356.5539171997925
# Колонка: short_model_SCION   -3533.3542277608317
# Колонка: short_model_SL   8684.120021793196
# Колонка: short_model_Saab   -3561.8419057952337
# Колонка: short_model_Scion   -9368.941567898783
# Колонка: short_model_Sea   -3.992441816080827e-05
# Колонка: short_model_Sterling   -5.7753699366003275e-05
# Колонка: short_model_Studebaker   -7051.260924550925
# Колонка: short_model_Suzuki   -8388.68537490079
# Колонка: short_model_THOMAS   -7885.604728976535
# Колонка: short_model_Thomas   0.00020539514321171737
# Колонка: short_model_Town   -4398.173998186625
# Колонка: short_model_Triumph   13916.217817480023
# Колонка: short_model_Voltswagon   -8346.116556786386
# Колонка: short_model_Xx   -30907.63843241831
# Колонка: short_model_a-class   -4938.823988299471
# Колонка: short_model_a3   -6864.226481492366
# Колонка: short_model_a3,   -4911.07378298804
# Колонка: short_model_a4   -4237.150607454547
# Колонка: short_model_a5   -104.45545649220514
# Колонка: short_model_a6   -576.3845032720503
# Колонка: short_model_a7   4742.458744226937
# Колонка: short_model_a8   -3049.2052203804824
# Колонка: short_model_acadia   -6917.556908541673
# Колонка: short_model_accent   140.55859224961233
# Колонка: short_model_accord   -3639.392631458612
# Колонка: short_model_all   -16133.153037971402
# Колонка: short_model_allante   5273.956978744118
# Колонка: short_model_allroad   412.8371415459545
# Колонка: short_model_altima   -11858.41111270619
# Колонка: short_model_am   10919.52339190451
# Колонка: short_model_amc   292.88892228667567
# Колонка: short_model_arcadia   -13991.279099222671
# Колонка: short_model_armada   -2386.476208447975
# Колонка: short_model_arteon   11909.520070945955
# Колонка: short_model_ascent   15725.98571694651
# Колонка: short_model_aspen   -0.00016088778193079634
# Колонка: short_model_astra   -4185.037168044467
# Колонка: short_model_astro   -5928.744946932184
# Колонка: short_model_atlas   7990.526493526107
# Колонка: short_model_ats   -5107.37465999188
# Колонка: short_model_aura   -926.4138036156394
# Колонка: short_model_autobiography   23134.724570900773
# Колонка: short_model_avalanche   1903.9982962144995
# Колонка: short_model_avalon   -4907.247103515875
# Колонка: short_model_avanger   -9613.015440491978
# Колонка: short_model_avenger   -9258.408049133634
# Колонка: short_model_aveo   -9178.613690757382
# Колонка: short_model_aviator   -5307.285201887763
# Колонка: short_model_azera   4.983978942618705e-05
# Колонка: short_model_aztek   -2100.3156029788247
# Колонка: short_model_b-class   4.842514954361832e-05
# Колонка: short_model_b-series   4120.097647833521
# Колонка: short_model_b2200   9527.886259982055
# Колонка: short_model_b2300   -2727.755644786831
# Колонка: short_model_b2600i   -0.0001392221338392119
# Колонка: short_model_baja   9434.114399644306
# Колонка: short_model_beetle   1387.8867862036848
# Колонка: short_model_bel   16005.272147971227
# Колонка: short_model_belair   43264.15704875507
# Колонка: short_model_benz   -2973.230515812957
# Колонка: short_model_blackwood   -0.0001116548173740739
# Колонка: short_model_blazer   -1369.221347044844
# Колонка: short_model_blue   -7781.061097114716
# Колонка: short_model_bolt   -3776.2398439528943
# Колонка: short_model_bonanza   -0.00017188383424127096
# Колонка: short_model_bonneville   -9516.421528684823
# Колонка: short_model_boxster   -12131.556969050565
# Колонка: short_model_bronco   13659.622674790124
# Колонка: short_model_brz   8203.239657857026
# Колонка: short_model_bug   5792.714714376091
# Колонка: short_model_bus   14277.02109371964
# Колонка: short_model_c   -10714.641386410565
# Колонка: short_model_c-10   24226.67818243946
# Колонка: short_model_c-7500   -4.139722204854479e-05
# Колонка: short_model_c-class   -351.818011550402
# Колонка: short_model_c-hr   -15600.013109686583
# Колонка: short_model_c-max   -13754.771640985791
# Колонка: short_model_c/k   0.0003099418781857821
# Колонка: short_model_c10   -131.8305109348729
# Колонка: short_model_c250   -8562.062754114577
# Колонка: short_model_c280   -8.856447402649792e-05
# Колонка: short_model_c30   7.660386472707614e-05
# Колонка: short_model_c300   -7421.650417451061
# Колонка: short_model_c4500   2552.0566473114613
# Колонка: short_model_c5500   1036.5651560116623
# Колонка: short_model_c60   7936.629086502412
# Колонка: short_model_c6500   -5.281036646920256e-05
# Колонка: short_model_c70   -678.6425801010076
# Колонка: short_model_c8500   14903.719515162446
# Колонка: short_model_cabellero   -4.598307782543998e-05
# Колонка: short_model_cabrio   7351.485878253207
# Колонка: short_model_caddilac   -10923.426567259272
# Колонка: short_model_cadenza   9203.43738235974
# Колонка: short_model_caliber   -5465.442018059382
# Колонка: short_model_camaro   3818.7178537707573
# Колонка: short_model_camary   -8.91838990355609e-05
# Колонка: short_model_camero   -9103.721548901416
# Колонка: short_model_camry   -6399.995111712695
# Колонка: short_model_canyon   -2849.533484988947
# Колонка: short_model_capri   0.00016414367564721033
# Колонка: short_model_caprice   595.1873203698194
# Колонка: short_model_captiva   -7414.774266275394
# Колонка: short_model_caravan   55.69642553559828
# Колонка: short_model_caravan/grand   -4410.086279525667
# Колонка: short_model_cargo   -27731.66441824363
# Колонка: short_model_cascada   -7406.304166725509
# Колонка: short_model_cavalier   3633.0892960311658
# Колонка: short_model_cayenne   -14090.164443488486
# Колонка: short_model_cayman   -334.7373939473753
# Колонка: short_model_cc   2839.9426860931344
# Колонка: short_model_cc300   -0.00018119325113730156
# Колонка: short_model_cc4500   18898.71519410767
# Колонка: short_model_century   -4210.102410723507
# Колонка: short_model_certified   7996.5120199923995
# Колонка: short_model_challenger   4574.827311862744
# Колонка: short_model_charger   -2967.5561143591885
# Колонка: short_model_cherokee   -9768.287233625748
# Колонка: short_model_chevelle   31178.35424296824
# Колонка: short_model_chevorlet   5930.935164924235
# Колонка: short_model_chryler   -6746.316861353139
# Колонка: short_model_chysler   -0.00024179951651603915
# Колонка: short_model_city   0.0001992300858546514
# Колонка: short_model_civic   -5826.733410084992
# Колонка: short_model_cj-5   -6931.675329728551
# Колонка: short_model_cj2a   -88.63849477994533
# Колонка: short_model_cj5   978.6779651654529
# Колонка: short_model_cj7   1959.0550142809593
# Колонка: short_model_cj8   1965.9487826956238
# Колонка: short_model_cl-class   5.312390385370236e-06
# Колонка: short_model_cla   -5343.216033708332
# Колонка: short_model_cla-class   -5393.8979165076535
# Колонка: short_model_clarity   -7113.198673061717
# Колонка: short_model_classic   -4331.3572203557405
# Колонка: short_model_classuc   6.59479628666304e-05
# Колонка: short_model_clk   -1473.49445655686
# Колонка: short_model_clk-class   -3544.940445804479
# Колонка: short_model_clk350   -4674.700464877153
# Колонка: short_model_cls-class   5667.561676263292
# Колонка: short_model_cls550   -4747.661372873821
# Колонка: short_model_clubman   -28606.5146047846
# Колонка: short_model_cmax   -11555.53368918221
# Колонка: short_model_cobalt   -8143.3620674597105
# Колонка: short_model_colbalt   -7296.550733860512
# Колонка: short_model_colorado   -1081.029860401809
# Колонка: short_model_comet   -0.00011421729459470953
# Колонка: short_model_commander   -7484.547729715054
# Колонка: short_model_compass   -14741.417797853594
# Колонка: short_model_concorde   -676.3119414630072
# Колонка: short_model_conquest   12665.41741450335
# Колонка: short_model_continental   6713.595025782357
# Колонка: short_model_convertible   -19442.802586107147
# Колонка: short_model_cooper   -26073.215132015124
# Колонка: short_model_corolla   -8289.492066712523
# Колонка: short_model_corsair   3524.6415288867656
# Колонка: short_model_corvette   12297.227447484054
# Колонка: short_model_cougar   -7341.579407391402
# Колонка: short_model_country   45.99572901266171
# Колонка: short_model_countryman   -17548.153428490165
# Колонка: short_model_coupe   6036.7801834014
# Колонка: short_model_cr-v   -1742.6589936691457
# Колонка: short_model_crew   8765.721907335324
# Колонка: short_model_crossfire   5375.629429263583
# Колонка: short_model_crosstour   -510.88928014520525
# Колонка: short_model_crosstrek   2619.1194386556795
# Колонка: short_model_crown   -9024.752833607838
# Колонка: short_model_cruze   -11018.201281833402
# Колонка: short_model_crv   -574.8536054413347
# Колонка: short_model_crz   -5155.706901488926
# Колонка: short_model_ct   -12318.935488333973
# Колонка: short_model_ct4   868.8882176680054
# Колонка: short_model_ct5   2494.956089155893
# Колонка: short_model_ct6   3529.6077657166134
# Колонка: short_model_cts   -3369.94734229265
# Колонка: short_model_cts-v   10626.931459395282
# Колонка: short_model_cts4   -7237.293530819208
# Колонка: short_model_cube   -11754.082595121165
# Колонка: short_model_cvr   -4.248295954312198e-05
# Колонка: short_model_cx-3   -10888.071514508008
# Колонка: short_model_cx-5   -6307.220564945699
# Колонка: short_model_cx-7   -2778.564439637725
# Колонка: short_model_cx-9   -2174.101961055995
# Колонка: short_model_cx7   -4568.685864308682
# Колонка: short_model_cx9   -0.00019072253053309396
# Колонка: short_model_d50   -5227.291020087508
# Колонка: short_model_dakota   -121.98628890554642
# Колонка: short_model_dart   -8527.770726669625
# Колонка: short_model_davidson   -3649.4715327803124
# Колонка: short_model_dealer*   13858.995514098075
# Колонка: short_model_defender   33172.11092978923
# Колонка: short_model_deisel   510.6516784285223
# Колонка: short_model_deluxe   8787.261362394176
# Колонка: short_model_denali   -4251.914929259682
# Колонка: short_model_deville   -4856.831705066699
# Колонка: short_model_diesel   -0.00024362598196603358
# Колонка: short_model_discovery   7966.946103741136
# Колонка: short_model_dts   -6458.237596310286
# Колонка: short_model_dump   8911.418914927717
# Колонка: short_model_duramax   -4362.225341204017
# Колонка: short_model_durango   1000.3252338936292
# Колонка: short_model_durangon   4949.939379853158
# Колонка: short_model_e   3228.776481681854
# Колонка: short_model_e-150   4278.952435258594
# Колонка: short_model_e-250   -3746.788776268372
# Колонка: short_model_e-350   -1916.0794122008392
# Колонка: short_model_e-450   4840.812226370382
# Колонка: short_model_e-class   660.1068907579969
# Колонка: short_model_e-golf   -1147.3145892926898
# Колонка: short_model_e-pace   4518.085423194293
# Колонка: short_model_e-series   -3214.3475239531576
# Колонка: short_model_e150   1515.8019842327353
# Колонка: short_model_e250   -6103.886747238881
# Колонка: short_model_e320   12438.386596470065
# Колонка: short_model_e350   -3289.8556836620496
# Колонка: short_model_e450   -8779.867856434508
# Колонка: short_model_e46   27577.759743350645
# Колонка: short_model_e500   -1791.1650639761667
# Колонка: short_model_echo   -7095.026034334344
# Колонка: short_model_eclipse   5886.160531297317
# Колонка: short_model_econoline   -31.815122889047018
# Колонка: short_model_ecosport   -8142.601037136203
# Колонка: short_model_edge   -6277.7164556985235
# Колонка: short_model_el   13974.228594342765
# Колонка: short_model_elantra   672.1860640643624
# Колонка: short_model_elcamino   5915.771357489981
# Колонка: short_model_eldorado   -3773.398903185986
# Колонка: short_model_element   -638.8795353523656
# Колонка: short_model_enclave   -943.0156954363001
# Колонка: short_model_encore   -10685.449878108831
# Колонка: short_model_endeavor   5052.661799623891
# Колонка: short_model_envision   -7281.363766636919
# Колонка: short_model_envoy   -5416.5874536722
# Колонка: short_model_eos   7237.019991764702
# Колонка: short_model_eqinox   -752.2195648416484
# Колонка: short_model_equinox   -6897.433840106784
# Колонка: short_model_es   -8823.26007542171
# Колонка: short_model_es300   -3.3899827940331306e-05
# Колонка: short_model_es330   -5099.059020073347
# Колонка: short_model_es350   -7800.4639536754175
# Колонка: short_model_escalade   5986.632399772715
# Колонка: short_model_escape   -9655.398147694847
# Колонка: short_model_escape-se,   -10489.586871824926
# Колонка: short_model_escort   -5300.946821533864
# Колонка: short_model_eurovan   36080.47019829317
# Колонка: short_model_evoque   -3941.565025284048
# Колонка: short_model_excursion   6672.232359312968
# Колонка: short_model_expedition   -235.58813160908312
# Колонка: short_model_explorer   -3426.315774736357
# Колонка: short_model_express   3356.430606261957
# Колонка: short_model_f   2596.9044662722063
# Колонка: short_model_f-100   -3272.247093949069
# Колонка: short_model_f-150   1478.510948795728
# Колонка: short_model_f-250   6385.483595638748
# Колонка: short_model_f-250sd   10799.551366136577
# Колонка: short_model_f-350   5781.091552169705
# Колонка: short_model_f-350sd   19353.070257199168
# Колонка: short_model_f-450   1134.2367144416773
# Колонка: short_model_f-450sd   17745.423876880363
# Колонка: short_model_f-550   2095.426615020575
# Колонка: short_model_f-650   -3.737856166660812
# Колонка: short_model_f-750   6221.997992337906
# Колонка: short_model_f-pace   5910.628219938616
# Колонка: short_model_f-type   7220.564056697349
# Колонка: short_model_f1   172.29221686630052
# Колонка: short_model_f100   1.5137738046178129e-05
# Колонка: short_model_f150   1787.9430858135247
# Колонка: short_model_f250   5595.682303688245
# Колонка: short_model_f350   4044.083155457638
# Колонка: short_model_f450   6172.514567679435
# Колонка: short_model_f450sd   -2.9497344257833902e-05
# Колонка: short_model_f50   8.962108950072434e-05
# Колонка: short_model_f550   11706.352796307028
# Колонка: short_model_f600   3782.2324869196304
# Колонка: short_model_f650   15738.79563301717
# Колонка: short_model_f700   5957.53158111429
# Колонка: short_model_f750   12726.654556928324
# Колонка: short_model_falcon   -0.00023054418761603301
# Колонка: short_model_fe   4.8962227538140723e-05
# Колонка: short_model_fiero   -3112.5843866005926
# Колонка: short_model_fiesta   -13820.386529975494
# Колонка: short_model_firebird   3252.3508920668123
# Колонка: short_model_fit   -9917.51441666847
# Колонка: short_model_five   -7561.603503266017
# Колонка: short_model_fj   9775.83066442853
# Колонка: short_model_fj40   13931.870551559507
# Колонка: short_model_fleetmaster   7931.050644876967
# Колонка: short_model_fleetwood   5.880444405192975e-06
# Колонка: short_model_flex   -6511.860825681094
# Колонка: short_model_focus   -12523.354020027939
# Колонка: short_model_fords   -4818.4713474287955
# Колонка: short_model_forester   4976.539079963813
# Колонка: short_model_forte   218.32882386869437
# Колонка: short_model_forte5   -50.928349295201315
# Колонка: short_model_foxbody   -2105.9591620325873
# Колонка: short_model_freestar   -9163.846885989757
# Колонка: short_model_freestyle   -5532.809753943969
# Колонка: short_model_freightliner   16165.235056942383
# Колонка: short_model_frontier   -4787.4665154020295
# Колонка: short_model_fusion   -11936.083743454108
# Колонка: short_model_fuso   8038.9573438090265
# Колонка: short_model_fx35   2641.0808361171153
# Колонка: short_model_fx45   1087.1161631614116
# Колонка: short_model_g   3844.746148708393
# Колонка: short_model_g-class   -2.914985998359043e-06
# Колонка: short_model_g.   -10947.782782840766
# Колонка: short_model_g20   -8.501861066179117e-05
# Колонка: short_model_g30   813.0913860732371
# Колонка: short_model_g35   4902.853252352718
# Колонка: short_model_g35x   3363.1435098006223
# Колонка: short_model_g37   2694.8053370900852
# Колонка: short_model_g37s   -187.4716232915643
# Колонка: short_model_g37x   -0.00012751602963589903
# Колонка: short_model_g4500   930.2793748413699
# Колонка: short_model_g5   -11007.882466512581
# Колонка: short_model_g6   -9091.408457324802
# Колонка: short_model_g8   196.14082239995682
# Колонка: short_model_galant   2656.8230231078683
# Колонка: short_model_genesis   7068.865213085495
# Колонка: short_model_ghia   18358.973678033108
# Колонка: short_model_gl   -12584.957568029018
# Колонка: short_model_gl-class   -717.5998137897018
# Колонка: short_model_gl450   0.00016467004070364055
# Колонка: short_model_gla   -4012.2490034524694
# Колонка: short_model_gla-class   5365.820810133493
# Колонка: short_model_gladiator   7543.050676538278
# Колонка: short_model_glc   -793.5834894278134
# Колонка: short_model_glc-class   4496.8788286822955
# Колонка: short_model_gle   3702.784823121511
# Колонка: short_model_gle-class   0.00016758098172431346
# Колонка: short_model_glk   -4843.979551688028
# Колонка: short_model_glk-class   -3260.080804850356
# Колонка: short_model_glk350   -0.00011561458063624741
# Колонка: short_model_gls   9094.43761462907
# Колонка: short_model_gmc/chev   1346.1195183222505
# Колонка: short_model_gmce   1191.4993853420149
# Колонка: short_model_gmt-400   2392.993202758266
# Колонка: short_model_golf   5413.3046702500105
# Колонка: short_model_gr   6.147618120166953e-05
# Колонка: short_model_grand   -6468.588880684463
# Колонка: short_model_grandville   9619.542201715121
# Колонка: short_model_grumman   3399.912566531304
# Колонка: short_model_gs   -4567.636445531898
# Колонка: short_model_gs350   2.6152915779675823e-05
# Колонка: short_model_gs430   -0.0003142497712360637
# Колонка: short_model_gt   8981.118627920987
# Колонка: short_model_gt-r   28081.116334344813
# Колонка: short_model_gti   3425.6259313177175
# Колонка: short_model_gto   10691.605355688629
# Колонка: short_model_gx   744.3782211388433
# Колонка: short_model_gx460   -0.00014399165320355678
# Колонка: short_model_gx470   0.00011006738714058883
# Колонка: short_model_hardbody   1483.6379906654315
# Колонка: short_model_hardtop   -24885.38761358284
# Колонка: short_model_hearse   4442.380209417603
# Колонка: short_model_hhr   -6712.655370989799
# Колонка: short_model_hiace   1551.1703663054288
# Колонка: short_model_high   5961.635307115478
# Колонка: short_model_highlander   170.03359089899647
# Колонка: short_model_hr-v   -10115.062861393224
# Колонка: short_model_hse   -2185.7675190611744
# Колонка: short_model_hummer   9994.324044607903
# Колонка: short_model_hyndai   -7390.598788439009
# Колонка: short_model_i-miev   -4.0369832277065143e-07
# Колонка: short_model_i3   -15598.905594692465
# Колонка: short_model_i30   -0.00010423440198792377
# Колонка: short_model_i35   3096.6861626915106
# Колонка: short_model_ilx   -3075.8108933247604
# Колонка: short_model_impala   -7888.13778400007
# Колонка: short_model_impreza   4856.393172887374
# Колонка: short_model_insight   -9401.146430719979
# Колонка: short_model_international   -2656.5725255155094
# Колонка: short_model_ion   -3166.1786073480057
# Колонка: short_model_ioniq   3094.2251890640846
# Колонка: short_model_is   -7920.53820740549
# Колонка: short_model_is250   -16275.353909847843
# Колонка: short_model_is300   -4416.368260751995
# Колонка: short_model_isf   8268.31355290958
# Колонка: short_model_isuzu   3733.824734701796
# Колонка: short_model_jeepster   -123.60810608679564
# Колонка: short_model_jetta   -136.4385043675711
# Колонка: short_model_jimmy   7.946998266561422e-05
# Колонка: short_model_jouney   -8736.510373123827
# Колонка: short_model_journey   -7460.808759020526
# Колонка: short_model_juke   -12495.941687199673
# Колонка: short_model_jx35   -0.00018077037020702846
# Колонка: short_model_k10   9690.418243154949
# Колонка: short_model_k20   -0.00017840742475527804
# Колонка: short_model_k30   20516.556065875207
# Колонка: short_model_k5   1765.5332542158017
# Колонка: short_model_k900   9059.930049496728
# Колонка: short_model_kicks   -12264.500911940635
# Колонка: short_model_kodiak   -1978.0402920240213
# Колонка: short_model_l   2888.312766172408
# Колонка: short_model_l300   -0.00011595656940244226
# Колонка: short_model_lacrosse   -4309.522013431259
# Колонка: short_model_lancer   3847.8306580252556
# Колонка: short_model_land   15358.893108409527
# Колонка: short_model_landcruiser   0.00024097006894407969
# Колонка: short_model_leaf   -14191.605107517858
# Колонка: short_model_legacy   3377.7565916017693
# Колонка: short_model_legend   5071.723038925409
# Колонка: short_model_lemans   21593.057734397495
# Колонка: short_model_lesabre   -1995.6899896564494
# Колонка: short_model_liberty   -11452.536169160661
# Колонка: short_model_lifted   9710.560824380842
# Колонка: short_model_lightning   0.0004307076237637375
# Колонка: short_model_limousine   1942.5432990289628
# Колонка: short_model_long   -8652.211581670925
# Колонка: short_model_lr2   -5674.54716166096
# Колонка: short_model_lr3   -2264.820719331305
# Колонка: short_model_lr4   -3255.0753454900637
# Колонка: short_model_ls   -1730.797365621547
# Колонка: short_model_ltd   -4507.9744658621885
# Колонка: short_model_lucerne   -5165.03733732642
# Колонка: short_model_lx   6540.3336490094625
# Колонка: short_model_lx450   18797.070334870663
# Колонка: short_model_m   -1783.2743744833929
# Колонка: short_model_m-class   -3542.6000585521165
# Колонка: short_model_m3   8172.807163022419
# Колонка: short_model_m35   1767.302275204651
# Колонка: short_model_m35s   2401.6990639435153
# Колонка: short_model_m5   -3.1889874662738293e-05
# Колонка: short_model_macan   -6.411317281163065e-05
# Колонка: short_model_magnum   -666.9625887701532
# Колонка: short_model_malibu   -7752.804730951441
# Колонка: short_model_mallinia   -718.741975099812
# Колонка: short_model_marineer,premier   -9472.26800578076
# Колонка: short_model_mariner   -13332.196597075203
# Колонка: short_model_mark   -3981.9213467112017
# Колонка: short_model_maserati   6443.423748779438
# Колонка: short_model_matrix   -5564.626002604815
# Колонка: short_model_maxima   -8961.098166348813
# Колонка: short_model_maximum   -5217.873635738954
# Колонка: short_model_mazda2   -7559.628183642628
# Колонка: short_model_mazda3   -6719.084042226946
# Колонка: short_model_mazda5   -5286.2308385999295
# Колонка: short_model_mazda6   -5558.711480482271
# Колонка: short_model_mazda6i   -4024.853714489883
# Колонка: short_model_md-x   -13973.437681529096
# Колонка: short_model_mdx   5461.2286318801025
# Колонка: short_model_mercades   -0.00021514061245397897
# Колонка: short_model_mercedes-amg   12513.33768225732
# Колонка: short_model_metris   -1589.6011209081157
# Колонка: short_model_mg   6330.467071788602
# Колонка: short_model_miata   3339.8891969023525
# Колонка: short_model_milan   -12791.633617814925
# Колонка: short_model_mirage   -7412.633616739457
# Колонка: short_model_mkc   -4477.621266268763
# Колонка: short_model_mks   -6474.466382795717
# Колонка: short_model_mkt   -3300.081209749822
# Колонка: short_model_mkx   -1999.7831436228494
# Колонка: short_model_mkz   -6453.760069746312
# Колонка: short_model_ml   -6159.237152143002
# Колонка: short_model_ml350   -1516.8129422702486
# Колонка: short_model_ml500   0.00010423095295664098
# Колонка: short_model_model   741.28820304109
# Колонка: short_model_monte   11727.687167453541
# Колонка: short_model_montero   5421.325313820623
# Колонка: short_model_mountaineer   -1054.2660089128183
# Колонка: short_model_mpv   -4967.6760832277105
# Колонка: short_model_mr2   2252.794133017911
# Колонка: short_model_murano   -8912.374004935136
# Колонка: short_model_mustang   45.316793090131114
# Колонка: short_model_mx-5   -1109.0748967284287
# Колонка: short_model_nautilus   3255.0640165508553
# Колонка: short_model_navigator   6737.507406678271
# Колонка: short_model_neon   -0.00022368950590134773
# Колонка: short_model_new   7019.843251149283
# Колонка: short_model_newport   0.00014632155307481298
# Колонка: short_model_niro   2311.629721008532
# Колонка: short_model_nitro   -6516.752862823743
# Колонка: short_model_nova   16750.35930918714
# Колонка: short_model_nv   -3704.8372391994694
# Колонка: short_model_nv1500   0.00031957965438778047
# Колонка: short_model_nv200   -10635.833100012682
# Колонка: short_model_nv2500   -2348.567953917169
# Колонка: short_model_nv2500hd   0.00015667262118768122
# Колонка: short_model_nx   -7081.414631744401
# Колонка: short_model_nx300   -7019.100819861492
# Колонка: short_model_oddyssey   -4.281859037291724e-05
# Колонка: short_model_odyssey   -2698.7016810476343
# Колонка: short_model_oldsmobile   -1022.2540487368502
# Колонка: short_model_optima   2251.718971886817
# Колонка: short_model_optimia   5368.154522261367
# Колонка: short_model_other   671.9650325035442
# Колонка: short_model_outback   5161.242564572017
# Колонка: short_model_outlander   254.85113907612777
# Колонка: short_model_outlook   1676.1720299614044
# Колонка: short_model_paceman   -26862.303755674267
# Колонка: short_model_pacifica   2551.248843354013
# Колонка: short_model_panamera   -3349.802103267562
# Колонка: short_model_panel   4980.561034116332
# Колонка: short_model_park   -2225.5128045486636
# Колонка: short_model_passat   126.2767965484673
# Колонка: short_model_passport   -766.1906549882023
# Колонка: short_model_pathfinder   -8004.083480548966
# Колонка: short_model_patriot   -16023.189987519921
# Колонка: short_model_phaeton   9441.071414771064
# Колонка: short_model_pick   3.277646828792058e-05
# Колонка: short_model_pickup   4288.035525269185
# Колонка: short_model_pilot   -339.4098711513568
# Колонка: short_model_plymouth   12694.467370314449
# Колонка: short_model_pontaic   -0.0003573668473109137
# Колонка: short_model_prelude   5620.7387948841915
# Колонка: short_model_prius   -7881.864489125275
# Колонка: short_model_prizm   -1653.1066488053448
# Колонка: short_model_promaster   -5626.3322057998175
# Колонка: short_model_protege   -2294.427601554808
# Колонка: short_model_pt   1287.206320056163
# Колонка: short_model_putback   8052.600417757614
# Колонка: short_model_q3   -3689.3650596880084
# Колонка: short_model_q5   -751.5753763869127
# Колонка: short_model_q50   1629.39765221763
# Колонка: short_model_q60   9518.363328477439
# Колонка: short_model_q7   -729.7485146504409
# Колонка: short_model_q70   3257.1191682391463
# Колонка: short_model_quattro   -5088.893079084268
# Колонка: short_model_quest   -6978.894226336284
# Колонка: short_model_qx50   106.68810965157445
# Колонка: short_model_qx56   252.85447982279123
# Колонка: short_model_qx60   4512.001622076927
# Колонка: short_model_qx70   2406.6047334206355
# Колонка: short_model_qx80   16121.363489143701
# Колонка: short_model_r-class   -8049.289571558392
# Колонка: short_model_r32   10291.493136861936
# Колонка: short_model_rabbit   5657.21723716695
# Колонка: short_model_rainier   -7519.640709148569
# Колонка: short_model_ram1500   2527.7859138794756
# Колонка: short_model_ram2500   4492.496190396412
# Колонка: short_model_ramcharger   -2871.086954365288
# Колонка: short_model_range   9063.123539670178
# Колонка: short_model_ranger   -3666.0101029293533
# Колонка: short_model_rat   7726.785579786906
# Колонка: short_model_rav   -5147.570898938995
# Колонка: short_model_rav4   -5311.9482444727855
# Колонка: short_model_rc   -5865.743941706587
# Колонка: short_model_rdx   2566.2476312945223
# Колонка: short_model_reatta   -3058.840286556955
# Колонка: short_model_rebel   12163.498974517033
# Колонка: short_model_regal   -6376.101646284598
# Колонка: short_model_rendezvous   -11505.862682037903
# Колонка: short_model_renegade   -14056.623995059588
# Колонка: short_model_replica   -5.340029201761354e-05
# Колонка: short_model_ridgeline   3036.050597159274
# Колонка: short_model_rio   -665.4773535622537
# Колонка: short_model_rivera   3779.8321176615273
# Колонка: short_model_riviera   2133.8310986900433
# Колонка: short_model_rl   2168.925348144089
# Колонка: short_model_rlx   366.42562370898526
# Колонка: short_model_roadmaster   3.1010574275569525e-05
# Колонка: short_model_roadster   -29245.704534921093
# Колонка: short_model_rogue   -10319.954521880376
# Колонка: short_model_romeo   -578.9046674917839
# Колонка: short_model_rondo   -0.00012539266390376724
# Колонка: short_model_rouge   -10310.858529309542
# Колонка: short_model_routan   -153.5118981707363
# Колонка: short_model_rs   -7.929078947199741e-05
# Колонка: short_model_rsx   -964.740172023385
# Колонка: short_model_rx   -4515.456016739875
# Колонка: short_model_rx-8   -2629.96894606575
# Колонка: short_model_rx300   -6429.8400571771745
# Колонка: short_model_rx330   -6871.194672142235
# Колонка: short_model_rx350   -13776.256874009945
# Колонка: short_model_rx400h   -5326.341771838189
# Колонка: short_model_rx7   661.3104267146941
# Колонка: short_model_rx8   -3744.6241873545946
# Колонка: short_model_s   17875.23784186518
# Колонка: short_model_s-10   -5.9984323343087453e-05
# Колонка: short_model_s-class   1623.2946865257527
# Колонка: short_model_s/w   -7.648886276001576e-05
# Колонка: short_model_s10   934.1718790000111
# Колонка: short_model_s2000   17037.423071726975
# Колонка: short_model_s3   -9272.097904465403
# Колонка: short_model_s320   6487.127018708641
# Колонка: short_model_s4   3403.487342164991
# Колонка: short_model_s40   -5020.508860523059
# Колонка: short_model_s430   -5067.644615624058
# Колонка: short_model_s5   9056.006556911398
# Колонка: short_model_s500   -4899.8278211998895
# Колонка: short_model_s6   7668.541735670247
# Колонка: short_model_s60   -5152.701136110464
# Колонка: short_model_s7   -7246.416695174367
# Колонка: short_model_s70   1430.3988994909703
# Колонка: short_model_s8   17779.250573623736
# Колонка: short_model_s90   -534.5578679646267
# Колонка: short_model_saab   -6381.266026830154
# Колонка: short_model_sable   -6021.191145834197
# Колонка: short_model_santa   6560.602705706966
# Колонка: short_model_sante   0.00021453602312249132
# Колонка: short_model_savana   -2409.044576983581
# Колонка: short_model_sc   -2135.6081986804447
# Колонка: short_model_sc2   -1801.750033447358
# Колонка: short_model_sc300   -826.5572453723631
# Колонка: short_model_school   -7290.583833368762
# Колонка: short_model_scion   -8051.397927753922
# Колонка: short_model_sebring   2147.315246804886
# Колонка: short_model_sedan   1413.3366974251512
# Колонка: short_model_sedona   3122.7350742861013
# Колонка: short_model_seirra   1788.8827312277929
# Колонка: short_model_sentra   -14505.52563750297
# Колонка: short_model_sequioa   -2.9436096156132407e-05
# Колонка: short_model_sequoia   2396.7524045226232
# Колонка: short_model_seville   446.40153377374776
# Колонка: short_model_shelby   -6.928854691068409e-05
# Колонка: short_model_sienna   -1300.2861455141353
# Колонка: short_model_sierra   3023.005969745932
# Колонка: short_model_sierra1500   -0.00012461554615583736
# Колонка: short_model_silverado   6395.271537830829
# Колонка: short_model_sky   4174.256997684024
# Колонка: short_model_skylark   -3716.63630743521
# Колонка: short_model_sl-class   9574.718040959362
# Колонка: short_model_sl2   -808.9664374000486
# Колонка: short_model_sl500   -0.00021799747037221096
# Колонка: short_model_sl55   6120.164880175693
# Колонка: short_model_sl550   2993.7603214510236
# Колонка: short_model_slc   8510.710368538612
# Колонка: short_model_sle   4058.8958062878264
# Колонка: short_model_slk   -1100.4469260055052
# Колонка: short_model_slk-class   -143.29411018082916
# Колонка: short_model_slt   -4179.371893859765
# Колонка: short_model_smart   -15072.86841194492
# Колонка: short_model_solara   -4192.666008010037
# Колонка: short_model_solstice   -0.00033658254778856644
# Колонка: short_model_sonata   2110.6603023942225
# Колонка: short_model_sonic   -12361.258235403924
# Колонка: short_model_sonoma   -37.242789621135216
# Колонка: short_model_sorento   6155.757511207733
# Колонка: short_model_sorrento   9.522989057586528e-05
# Колонка: short_model_soul   1201.231746347992
# Колонка: short_model_soul+   1775.9311814770208
# Колонка: short_model_spark   -15230.539902257502
# Колонка: short_model_spectra   6539.175120963991
# Колонка: short_model_sport   7789.142500843212
# Колонка: short_model_sportage   2697.65021732913
# Колонка: short_model_sprinter   2463.1165171872035
# Колонка: short_model_srx   -4143.829569079289
# Колонка: short_model_srx-v6   -4381.901499739886
# Колонка: short_model_srx4   -3186.139003451296
# Колонка: short_model_srx~awesome   -8865.461714591578
# Колонка: short_model_ss   11465.058322965919
# Колонка: short_model_ssr   8671.359313326093
# Колонка: short_model_starcraft   -19458.23820828908
# Колонка: short_model_step-van   9.835912214839482e-05
# Колонка: short_model_stinger   14346.882294053503
# Колонка: short_model_stratus   -4908.172509005082
# Колонка: short_model_sts   -7314.571725222441
# Колонка: short_model_studebaker   -2989.157233943029
# Колонка: short_model_suburban   4334.7376731939485
# Колонка: short_model_super   9074.31489795717
# Колонка: short_model_supra   -4.54724722658284e-05
# Колонка: short_model_suv   -5343.079690939474
# Колонка: short_model_suzuki   -5909.8915455832075
# Колонка: short_model_svx   15460.098644818057
# Колонка: short_model_t   -8470.322738527584
# Колонка: short_model_t-350   -493.6714843826587
# Колонка: short_model_t-bucket   5468.4556355552395
# Колонка: short_model_tacoma   3718.0818674022207
# Колонка: short_model_tahoe   4261.077603327443
# Колонка: short_model_tarsus   -8147.214496826517
# Колонка: short_model_taurus   -8372.995297318917
# Колонка: short_model_tc5500   28543.152519505653
# Колонка: short_model_telluride   17952.966497904552
# Колонка: short_model_tercel   -1751.6840226858062
# Колонка: short_model_terrain   -9893.47558027327
# Колонка: short_model_thing   18059.142305591497
# Колонка: short_model_thomas   -6492.532952443306
# Колонка: short_model_thrift   -2581.732809938216
# Колонка: short_model_thunderbird   15878.497104976412
# Колонка: short_model_tiguan   1949.2490075325668
# Колонка: short_model_titan   -2328.8964006593824
# Колонка: short_model_tl   -336.0267755750751
# Колонка: short_model_tlx   2104.141467056551
# Колонка: short_model_torrent   -10977.74216425967
# Колонка: short_model_touareg   6337.182997287959
# Колонка: short_model_town   914.291059732942
# Колонка: short_model_tracker   -5231.233088216722
# Колонка: short_model_tractor   -1237.4500411182692
# Колонка: short_model_trailblazer   -2365.7464182280014
# Колонка: short_model_trans   -0.00035793390816252213
# Колонка: short_model_transit   -3718.855924690696
# Колонка: short_model_traverse   -2994.1890495785506
# Колонка: short_model_trax   -12409.71331696507
# Колонка: short_model_tribeca   6838.260063753809
# Колонка: short_model_tribute   -5989.740650546097
# Колонка: short_model_triumph   -4368.949193070481
# Колонка: short_model_truck   -446.5930444932212
# Колонка: short_model_tsx   -89.78062885923717
# Колонка: short_model_tt   3712.3129368450723
# Колонка: short_model_tucson   5547.675777253249
# Колонка: short_model_tudor   35620.678245990304
# Колонка: short_model_tundra   6459.048749224735
# Колонка: short_model_uplander   -6.42215964035131e-05
# Колонка: short_model_utility   0.00037278776835592
# Колонка: short_model_ux   -7497.8118137347965
# Колонка: short_model_v50   -8386.845427922823
# Колонка: short_model_v6   24101.920576157183
# Колонка: short_model_v60   -33042.54112278235
# Колонка: short_model_v90   -29591.178366204233
# Колонка: short_model_van   3004.1020858880893
# Колонка: short_model_vanagon   15839.744350110679
# Колонка: short_model_vandura   6016.79788107284
# Колонка: short_model_velar   19702.192392702313
# Колонка: short_model_veloster   3760.4735391910403
# Колонка: short_model_venture   -527.8115617891608
# Колонка: short_model_venza   -2056.6533468427906
# Колонка: short_model_veracruz   7170.664900179579
# Колонка: short_model_verano   -11906.42789537178
# Колонка: short_model_versa   -16755.97267297152
# Колонка: short_model_vibe   -7878.54602981003
# Колонка: short_model_villager   -6688.531507159206
# Колонка: short_model_vnl   4776.223660233324
# Колонка: short_model_volt   -11224.92300961492
# Колонка: short_model_voyager   1545.8899903662043
# Колонка: short_model_vtx1300c   -11081.472573907355
# Колонка: short_model_vue   -2222.265531258629
# Колонка: short_model_w350   9958.983694200062
# Колонка: short_model_willys   7550.283627657561
# Колонка: short_model_windstar   -366.941577893768
# Колонка: short_model_wrangler   -660.3013783124024
# Колонка: short_model_wrx   7686.860798672013
# Колонка: short_model_x-3   -1.5184617268459988e-05
# Колонка: short_model_x-type   -3784.458708747031
# Колонка: short_model_x1   -8005.479425906486
# Колонка: short_model_x2   -1643.9565143087802
# Колонка: short_model_x3   -3528.3158090113793
# Колонка: short_model_x4   -1142.202053549313
# Колонка: short_model_x5   -3593.9656959959125
# Колонка: short_model_x6   8302.396711788328
# Колонка: short_model_xc   -7892.499705937717
# Колонка: short_model_xc40   -28748.2775926034
# Колонка: short_model_xc60   -3726.3473058522577
# Колонка: short_model_xc70   -2660.9659367849563
# Колонка: short_model_xc90   1517.494275894413
# Колонка: short_model_xe   -7047.055250707452
# Колонка: short_model_xf   -1655.6257960632106
# Колонка: short_model_xj   -8099.480846359363
# Колонка: short_model_xj-series   7750.87646559322
# Колонка: short_model_xj8   -1711.3728305028467
# Колонка: short_model_xk8   -1303.8250277915638
# Колонка: short_model_xt4   1930.4954747618572
# Колонка: short_model_xt5   4434.639220796623
# Колонка: short_model_xt6   21164.044737967066
# Колонка: short_model_xterra   -3715.0905410932023
# Колонка: short_model_xts   -4303.138927692947
# Колонка: short_model_xv   5489.781193064196
# Колонка: short_model_yaris   -8696.483131930776
# Колонка: short_model_yukon   323.30209855053306
# Колонка: short_model_z   -4024.2092411584467
# Колонка: short_model_z3   -1430.9459234602668
# Колонка: short_model_z4   5973.455803549407
# Колонка: short_model_zephyr   3.078549343626946e-05
# Колонка: short_model_zx2   -7379.282343663373
# Колонка: transmission_automatic   -457.77007322067766
# Колонка: transmission_manual   781.9940423958342
# Колонка: transmission_other   -324.2208312323237
# Колонка: region_SF bay area   -1234.857149504003
# Колонка: region_abilene   6494.335192606603
# Колонка: region_akron / canton   -451.2176085109079
# Колонка: region_albany   -1040.501794598218
# Колонка: region_albuquerque   1344.2277322304767
# Колонка: region_altoona-johnstown   -135.0291020596403
# Колонка: region_amarillo   -3628.233458391927
# Колонка: region_ames   3695.2421239390223
# Колонка: region_anchorage / mat-su   333.4417978409954
# Колонка: region_ann arbor   233.80283198927737
# Колонка: region_annapolis   5386.501615273955
# Колонка: region_appleton-oshkosh-FDL   -443.3456081152174
# Колонка: region_asheville   1964.7741454337356
# Колонка: region_ashtabula   757.1901653401567
# Колонка: region_athens   534.185737344989
# Колонка: region_atlanta   -276.8442753305392
# Колонка: region_auburn   -4886.18655387275
# Колонка: region_augusta   1953.5071643779409
# Колонка: region_austin   -105.16722292695715
# Колонка: region_bakersfield   3316.7002228294396
# Колонка: region_baltimore   163.53923280002368
# Колонка: region_baton rouge   -768.7098113875851
# Колонка: region_battle creek   1351.7941481057562
# Колонка: region_beaumont / port arthur   197.09154836448502
# Колонка: region_bellingham   -1651.3887364128325
# Колонка: region_bemidji   908.3983605061721
# Колонка: region_bend   -1649.5637668587324
# Колонка: region_billings   619.5033633676101
# Колонка: region_binghamton   -2790.545283373115
# Колонка: region_birmingham   1494.869697547717
# Колонка: region_bismarck   -1652.2882754602265
# ...
# Колонка: region_knoxville   2253.351114808159
# Колонка: region_kokomo   -1550.1488746362513
# Колонка: region_la crosse   736.2855514598668
# Колонка: region_la salle co   -373.8077925655682
# Колонка: region_lafayette   -2180.470103570907
# Колонка: region_lafayette / west lafayette   841.4588600840214
# Колонка: region_lake charles   -3424.9022105845443
# Колонка: region_lake of the ozarks   -5087.223818942214
# Колонка: region_lakeland   1984.1621392687034
# Колонка: region_lancaster   2677.2102162585256
# Колонка: region_lansing   1988.647378970829
# Колонка: region_laredo   -938.287747869625
# Колонка: region_las cruces   1435.835994993583
# Колонка: region_las vegas   -3671.3742973670533
# Колонка: region_lawrence   -2460.455718842669
# Колонка: region_lawton   -92.6348342010022
# Колонка: region_lehigh valley   712.5349701368668
# Колонка: region_lewiston / clarkston   1551.77994957388
# Колонка: region_lexington   337.2409030633758
# Колонка: region_lima / findlay   1648.0268854616381
# Колонка: region_lincoln   -5236.038813990882
# Колонка: region_little rock   2604.19901103428
# Колонка: region_logan   2924.8213322549723
# Колонка: region_long island   -123.25085822645929
# Колонка: region_los angeles   -1776.8119720002546
# Колонка: region_louisville   -104.28948769762951
# Колонка: region_lubbock   -4644.655147026028
# Колонка: region_lynchburg   -396.33420842058274
# Колонка: region_macon / warner robins   -650.2283218914333
# Колонка: region_madison   -437.8959331790966
# Колонка: region_maine   -96.71298313345096
# Колонка: region_manhattan   -333.6980664558736
# Колонка: region_mankato   -777.3165637864316
# Колонка: region_mansfield   2316.875873231498
# Колонка: region_mason city   2760.173391089901
# Колонка: region_mattoon-charleston   11814.64209941532
# Колонка: region_mcallen / edinburg   -856.4098287947062
# Колонка: region_meadville   -1825.2141583066136
# Колонка: region_medford-ashland   -2110.935926029049
# Колонка: region_memphis   702.72604032155
# Колонка: region_mendocino county   1059.7455712289234
# Колонка: region_merced   2413.8716787919775
# Колонка: region_milwaukee   -1669.6122146705939
# Колонка: region_minneapolis / st paul   -35.454465092335795
# Колонка: region_missoula   1703.1851870602577
# Колонка: region_mobile   -3197.68214129206
# Колонка: region_modesto   2228.9798895713384
# Колонка: region_mohave county   -5367.42951881442
# Колонка: region_monroe   379.25269348965844
# Колонка: region_monterey bay   407.6308954765774
# Колонка: region_montgomery   -708.5949740855253
# Колонка: region_morgantown   1364.346554372817
# Колонка: region_moses lake   -5208.927920377645
# Колонка: region_muncie / anderson   1052.278848829459
# Колонка: region_muskegon   -322.7163089891165
# Колонка: region_myrtle beach   16.262382290228743
# Колонка: region_nashville   629.6164650843934
# Колонка: region_new hampshire   -459.3960979258254
# Колонка: region_new haven   1214.9252020537594
# Колонка: region_new orleans   -4427.463023196535
# Колонка: region_new river valley   -1655.1232726425228
# Колонка: region_new york city   -1834.61981953452
# Колонка: region_norfolk / hampton roads   472.6608582212251
# Колонка: region_north central FL   -1528.3990776119124
# Колонка: region_north dakota   -483.15818676355053
# Колонка: region_north jersey   -1311.9733278305503
# Колонка: region_north mississippi   2606.470360551352
# Колонка: region_north platte   6283.504983894862
# Колонка: region_northeast SD   -4967.271301600951
# Колонка: region_northern WI   -3718.1005791695648
# Колонка: region_northern michigan   2538.6901346600853
# Колонка: region_northern panhandle   560.0472713437405
# Колонка: region_northwest CT   -980.1437547161152
# Колонка: region_northwest GA   -1795.4485610155725
# Колонка: region_northwest KS   68.12307755370279
# Колонка: region_northwest OK   1951.7385966322383
# Колонка: region_ocala   -710.307064197908
# Колонка: region_odessa / midland   4088.3455300349615
# Колонка: region_ogden-clearfield   376.79239839489486
# Колонка: region_okaloosa / walton   -6659.284725110995
# Колонка: region_oklahoma city   -1517.7956051121475
# Колонка: region_olympic peninsula   4557.277116269439
# Колонка: region_omaha / council bluffs   2171.068136183394
# Колонка: region_oneonta   781.643049215594
# Колонка: region_orange county   840.0485114401338
# Колонка: region_oregon coast   2044.5226001048497
# Колонка: region_orlando   -2661.1946353676863
# Колонка: region_outer banks   2139.227519066379
# Колонка: region_owensboro   -3280.2553567167765
# Колонка: region_palm springs   441.2491058088188
# Колонка: region_panama city   -2228.069390731054
# Колонка: region_parkersburg-marietta   -3739.9148591061535
# Колонка: region_pensacola   9564.20626491302
# Колонка: region_peoria   -850.768190585197
# Колонка: region_philadelphia   -1953.45035311128
# Колонка: region_phoenix   -791.6652982139356
# Колонка: region_pierre / central SD   14891.414759473793
# Колонка: region_pittsburgh   704.4339921010944
# Колонка: region_plattsburgh-adirondacks   -108.62468454931377
# Колонка: region_poconos   -2197.6491987905365
# Колонка: region_port huron   2781.5767542043595
# Колонка: region_portland   -1511.1824678161179
# Колонка: region_potsdam-canton-massena   -4749.831011331143
# Колонка: region_prescott   2478.8086723779084
# Колонка: region_pueblo   4199.979625601738
# Колонка: region_pullman / moscow   5581.026469064127
# Колонка: region_quad cities, IA/IL   -628.7107200977086
# Колонка: region_raleigh / durham / CH   1958.7740582512401
# Колонка: region_rapid city / west SD   -2544.0126829244155
# Колонка: region_reading   904.0785195551833
# Колонка: region_redding   606.2543955131409
# Колонка: region_reno / tahoe   1426.386779288986
# Колонка: region_rhode island   393.32094178746956
# Колонка: region_richmond   1045.9527724799623
# Колонка: region_roanoke   2592.1260712828375
# Колонка: region_rochester   -1506.855786603127
# Колонка: region_rockford   -2869.726683206012
# Колонка: region_roseburg   -560.4764528549238
# Колонка: region_roswell / carlsbad   -969.390154173861
# Колонка: region_sacramento   346.30736012053626
# Колонка: region_saginaw-midland-baycity   -29.719216289569886
# Колонка: region_salem   1301.0152279656425
# Колонка: region_salina   2553.5833189528876
# Колонка: region_salt lake city   -720.1087029729224
# Колонка: region_san angelo   2500.9242471267034
# Колонка: region_san antonio   -1076.2244993059703
# Колонка: region_san diego   1358.7512786435277
# Колонка: region_san luis obispo   1876.8250094260713
# Колонка: region_san marcos   4776.105444825347
# Колонка: region_sandusky   2838.5644794627556
# Колонка: region_santa barbara   310.9409594375011
# Колонка: region_santa fe / taos   -344.42775098061674
# Колонка: region_santa maria   2979.9089325107034
# Колонка: region_sarasota-bradenton   -524.0864118263653
# Колонка: region_savannah / hinesville   -755.4692019335619
# Колонка: region_scottsbluff / panhandle   1804.2390884001018
# Колонка: region_scranton / wilkes-barre   1629.1192895865502
# Колонка: region_seattle-tacoma   -978.230392342994
# Колонка: region_sheboygan   1432.7675386099772
# Колонка: region_show low   7987.152320155607
# Колонка: region_shreveport   -4110.14524648708
# Колонка: region_sierra vista   -4296.639863887298
# Колонка: region_sioux city   -1589.444259622013
# Колонка: region_sioux falls / SE SD   -1990.3804464652717
# Колонка: region_siskiyou county   -3094.2851708558405
# Колонка: region_skagit / island / SJI   -3733.4294063419834
# Колонка: region_south bend / michiana   -313.0001353906375
# Колонка: region_south coast   2783.2351420872633
# Колонка: region_south dakota   -3606.7048835710184
# Колонка: region_south florida   -4886.169507392701
# Колонка: region_south jersey   1064.1430313826108
# Колонка: region_southeast IA   -5692.536564887534
# Колонка: region_southeast alaska   -1229.442594993907
# Колонка: region_southeast missouri   561.7932187976078
# Колонка: region_southern WV   8281.33312926759
# Колонка: region_southern illinois   2136.2801290641582
# Колонка: region_southern maryland   1145.2457718476803
# Колонка: region_southwest KS   4710.1852818817115
# Колонка: region_southwest MN   3668.2252023131146
# Колонка: region_southwest MS   374.5486771340001
# Колонка: region_southwest VA   -6.54937557555968e-05
# Колонка: region_southwest michigan   -197.6179207992883
# Колонка: region_space coast   -620.5409318809044
# Колонка: region_spokane / coeur d'alene   -307.62352393631204
# Колонка: region_springfield   187.3868567199995
# Колонка: region_st augustine   -7725.509100363633
# Колонка: region_st cloud   -382.0607853191922
# Колонка: region_st george   -904.5649820211436
# Колонка: region_st joseph   172.04486383120232
# Колонка: region_st louis, MO   131.8420275653006
# Колонка: region_state college   -4636.990232959978
# Колонка: region_statesboro   -2933.913424547272
# Колонка: region_stillwater   -4374.000491164473
# Колонка: region_stockton   620.1144795630787
# Колонка: region_susanville   2276.958314070675
# Колонка: region_syracuse   -1422.358558266156
# Колонка: region_tallahassee   -4065.8071595905317
# Колонка: region_tampa bay area   -1789.8434805180887
# Колонка: region_terre haute   -2209.54531840784
# Колонка: region_texarkana   4054.0071880320384
# Колонка: region_texoma   4105.947390455993
# Колонка: region_the thumb   2126.084468075119
# Колонка: region_toledo   -1460.379961722705
# Колонка: region_topeka   -1719.8528562406798
# Колонка: region_treasure coast   -1429.4314955183559
# Колонка: region_tri-cities   4124.257464963298
# Колонка: region_tucson   -2267.59886496488
# Колонка: region_tulsa   340.6361302526892
# Колонка: region_tuscaloosa   -5230.261120059702
# Колонка: region_tuscarawas co   5496.361675715442
# Колонка: region_twin falls   -4240.3068560083275
# Колонка: region_twin tiers NY/PA   365.7252105920262
# Колонка: region_tyler / east TX   -12.022662846376306
# Колонка: region_upper peninsula   -1061.7571328131705
# Колонка: region_utica-rome-oneida   -1813.3180916110032
# Колонка: region_valdosta   5044.766461409017
# Колонка: region_ventura county   -325.703309226623
# Колонка: region_vermont   86.07625091015552
# Колонка: region_victoria   -2411.623662340497
# Колонка: region_visalia-tulare   -200.89305122167974
# Колонка: region_waco   1303.4150416005402
# Колонка: region_washington, DC   -182.8145773595678
# Колонка: region_waterloo / cedar falls   1719.2173742507505
# Колонка: region_watertown   -1608.4515409347441
# Колонка: region_wausau   -1821.0329638900555
# Колонка: region_wenatchee   -3328.6239648998885
# Колонка: region_western KY   4155.828265427872
# Колонка: region_western maryland   -1229.9066168613103
# Колонка: region_western massachusetts   -799.3496324279439
# Колонка: region_western slope   2345.4569638922244
# Колонка: region_wichita   -108.47976686888353
# Колонка: region_wichita falls   1622.0727615949716
# Колонка: region_williamsport   -1149.1528663338488
# Колонка: region_wilmington   372.43915259208546
# Колонка: region_winchester   -2581.6958300219235
# Колонка: region_winston-salem   2115.028253762722
# Колонка: region_worcester / central MA   -1377.0556225066384
# Колонка: region_wyoming   603.8447471059224
# Колонка: region_yakima   -866.7912107042303
# Колонка: region_york   1635.3424398487593
# Колонка: region_youngstown   276.9253283259998
# Колонка: region_yuba-sutter   -941.3594395738002
# Колонка: region_yuma   6973.409229704903
# Колонка: region_zanesville / cambridge   -2306.8724708177856
# Колонка: manufacturer_acura   -3348.2715369538428
# Колонка: manufacturer_alfa-romeo   -578.9046856363511
# Колонка: manufacturer_audi   254.30201397985775
# Колонка: manufacturer_bmw   2717.602469411806
# Колонка: manufacturer_buick   -657.3209232706222
# Колонка: manufacturer_cadillac   143.35159861564307
# Колонка: manufacturer_chevrolet   -184.76319400125294
# Колонка: manufacturer_chrysler   -8188.761144330991
# Колонка: manufacturer_datsun   5636.788734910271
# Колонка: manufacturer_dodge   -874.7371092147591
# Колонка: manufacturer_ferrari   0.0
# Колонка: manufacturer_fiat   -9026.995196616394
# Колонка: manufacturer_ford   1073.9076579220473
# Колонка: manufacturer_gmc   3698.013251911702
# Колонка: manufacturer_harley-davidson   -3649.471517571082
# Колонка: manufacturer_honda   -483.7461206561702
# Колонка: manufacturer_hyundai   -12677.134219672149
# Колонка: manufacturer_infiniti   -4898.752472682991
# Колонка: manufacturer_jaguar   1798.3363949241452
# Колонка: manufacturer_jeep   5699.521535472736
# Колонка: manufacturer_kia   -12801.315573107948
# Колонка: manufacturer_lexus   6260.229443262107
# Колонка: manufacturer_lincoln   766.6580540732948
# Колонка: manufacturer_mazda   -2058.7123467042816
# Колонка: manufacturer_mercedes-benz   1919.3742899359502
# Колонка: manufacturer_mercury   4719.698400896598
# Колонка: manufacturer_mini   17606.86517045078
# Колонка: manufacturer_mitsubishi   -10268.342633093187
# Колонка: manufacturer_nissan   3089.1240151533234
# Колонка: manufacturer_other   -688.9214997785698
# Колонка: manufacturer_pontiac   2290.693273602489
# Колонка: manufacturer_porsche   19203.57278969798
# Колонка: manufacturer_ram   3662.5644594963396
# Колонка: manufacturer_rover   1760.2386188008736
# Колонка: manufacturer_saturn   -4371.870035471067
# Колонка: manufacturer_subaru   -9700.082595031976
# Колонка: manufacturer_tesla   10472.416868385528
# Колонка: manufacturer_toyota   471.4981894335706
# Колонка: manufacturer_volkswagen   -9564.273786199527
# Колонка: manufacturer_volvo   777.6171499739932
# Колонка: state_ak   -4704.0777517437755
# Колонка: state_al   259.6168491264293
# Колонка: state_ar   -3455.8794402241656
# Колонка: state_az   1982.565252366473
# Колонка: state_ca   -1168.0223969861927
# Колонка: state_co   -1558.2160548713891
# Колонка: state_ct   26.0116686317549
# Колонка: state_dc   -182.81461779162737
# Колонка: state_de   -188.0872304884316
# Колонка: state_fl   2808.940842178343
# Колонка: state_ga   1864.7375437670935
# Колонка: state_hi   -640.8673740540363
# Колонка: state_ia   -2805.654742284585
# Колонка: state_id   -1460.6450640143325
# Колонка: state_il   -126.2019708486689
# Колонка: state_in   1350.115562877866
# Колонка: state_ks   962.1565887470051
# Колонка: state_ky   314.9067677679443
# Колонка: state_la   5431.692076432322
# Колонка: state_ma   -318.3555679934682
# Колонка: state_md   995.3148976011388
# Колонка: state_me   -96.71276858174747
# Колонка: state_mi   -1727.266598668156
# Колонка: state_mn   -354.2087440688056
# Колонка: state_mo   1068.5218879621912
# Колонка: state_ms   -1204.5254099152003
# Колонка: state_mt   -35.8890627344457
# Колонка: state_nc   437.48658618087075
# Колонка: state_nd   -2135.446643188813
# Колонка: state_ne   2965.429865482239
# Колонка: state_nh   -459.39591799593427
# Колонка: state_nj   -714.1786221943166
# Колонка: state_nm   -1684.3575654316148
# Колонка: state_nv   1637.468330744925
# Колонка: state_ny   935.1442965253241
# Колонка: state_oh   -289.18611392367075
# Колонка: state_ok   413.8916617208131
# Колонка: state_or   -1468.8772304790782
# Колонка: state_pa   -346.17209890930735
# Колонка: state_ri   393.32154732728776
# Колонка: state_sc   1419.054727401888
# Колонка: state_sd   1783.0459712840268
# Колонка: state_tn   -692.4699013848121
# Колонка: state_tx   2050.5838824653874
# Колонка: state_ut   1676.9393744417857
# Колонка: state_va   -329.29896154077824
# Колонка: state_vt   86.0760034832283
# Колонка: state_wa   299.936042858978
# Колонка: state_wi   -1017.804373671187
# Колонка: state_wv   -2602.187810746383
# Колонка: state_wy   603.8449284114795
# Колонка: title_status_clean   1602.168248692848
# Колонка: title_status_lien   654.3971711655597
# Колонка: title_status_missing   -2675.1129755428883
# Колонка: title_status_parts only   5199.103880378649
# Колонка: title_status_rebuilt   -2175.4454584955392
# Колонка: title_status_salvage   -2605.1119091967958
# Колонка: age_category_average   -1601.9762687552466
# Колонка: age_category_new   1177.4095072862542
# Колонка: age_category_old   424.56811567897967
# Колонка: lat_std   943.3229070175166
# Колонка: long_std   -801.7603844486757
# Колонка: year_std   2803.980667721855
# Колонка: desc_len_std   578.1635725025253
# Колонка: model_in_desc_std   191.51210468233512
# Колонка: model_len_std   25.182235765332734
# Колонка: model_word_count_std   643.9505503470737
# Колонка: month_std   -166.69160382996688
# Колонка: dayofweek_std   23.050435609510714
# Колонка: diff_years_std   -2803.980660371906

# %%
print('Нулевые кэфы:')
for col, i in zip(train.drop(columns=['price']), lr.coef_):
    if i==0:
        print(f'{col}')
# Out:
# Нулевые кэфы:
# manufacturer_ferrari

# %%
new_df = df.copy()
new_df = new_df.drop(columns=['odometer/price_std', 'price_category', 'manufacturer_ferrari'])

train, test = train_test_split(new_df, test_size=0.3, random_state=42)

lr = LinearRegression()
lr.fit(train.drop(columns=['price']), train.price)
pred = lr.predict(test.drop(columns=['price']))
mean_absolute_error(test.price, pred)
# Out:
# 4600.341117586319

# %% [markdown]
# **Задача 2. Логистическая регрессия**
#
# Теперь в рамках тех же данных попробуйте предсказать `price_category` с помощью алгоритма логистической регрессии. Предварительно из датафрейма удалите переменные, в которых косвенно содержится информация о целевой переменной (`odometer/price_std`, `price`).
#
# Для обученной модели:
#
# - рассчитайте и выведите метрику качества (accuracy) на тренировочной выборке;
# - сделайте предикт на тестовых данных и положите его в переменную `logreg_pred`;
# - рассчитайте и выведите accuracy и confusion_matrix на тестовой выборке.
#
# Обратите внимание, что это задание засчитывается, если:
# - accuracy на тренировочной выборке > 87%;
# - accuracy на тестовой выборке > 75.5%.
#
# Для улучшения метрики можно преобразовывать входные данные и тюнить параметры логистической регрессии.

# %%
new_df = df.drop(columns=['odometer/price_std', 'price'])

# %%
# Ваш код подготовки данных здесь. Допишите инициализацию входных фичей и целевую переменную
x = new_df.drop(columns='price_category')
y = new_df.price_category

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
ytrain_pred = logreg.predict(x_train)
accuracy_score(y_train, ytrain_pred)
# Out:
# 0.3392247140947572

# %%
logreg_pred = logreg.predict(x_test)
accuracy_score(y_test, logreg_pred)
# Out:
# 0.32432432432432434

# %%
confusion_matrix(y_test, logreg_pred)
# Out:
# array([[  0,   0, 997],
#        [  0,   0, 953],
#        [  0,   0, 936]])

# %%
logreg.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
new_df = df.drop(columns=['odometer/price_std', 'price', 'id'])

x = new_df.drop(columns='price_category')
y = new_df.price_category

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
logreg_tuned = LogisticRegression(C=4, max_iter = 1000)
logreg_tuned.fit(x_train, y_train)
ytrain_pred2 = logreg_tuned.predict(x_train)
accuracy_score(y_train, ytrain_pred2)
# Out:
# 0.8823704143769494

# %%
logreg_pred2 = logreg_tuned.predict(x_test)
accuracy_score(y_test, logreg_pred2)
# Out:
# 0.7616077616077616

# %%
confusion_matrix(y_test, logreg_pred2)
# Out:
# array([[804,  23, 170],
#        [ 24, 770, 159],
#        [149, 164, 623]])

# %% [markdown]
# **Задача 3. Многослойный персептрон**
#
# Решите задачу, поставленную в предыдущем задании, применив модель многослойного персептрона. С помощью данного алгоритма добейтесь лучших значений точности на тренировочной и тестовой выборках, чем на логистической регрессии.
#
# Увеличение точности в данном задании, по сравнению с предыдущим, должно быть больше увеличения 0.01 по метрике accuracy.

# %%
new_df = df.drop(columns=['odometer/price_std', 'price', 'id'])

x = new_df.drop(columns='price_category')
y = new_df.price_category

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
mlp = MLPClassifier(random_state=42, max_iter=500, hidden_layer_sizes=(100,20), activation='tanh')
mlp.get_params()
# Out:
# {'activation': 'tanh',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': (100, 20),
#  'learning_rate': 'constant',
#  'learning_rate_init': 0.001,
#  'max_fun': 15000,
#  'max_iter': 500,
#  'momentum': 0.9,
#  'n_iter_no_change': 10,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': 42,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
mlp.fit(x_train, y_train)
mlp_train_pred = mlp.predict(x_train)

accuracy_score(y_train, mlp_train_pred)
# Out:
# 1.0

# %%
mlp_test_pred = mlp.predict(x_test)

accuracy_score(y_test, mlp_test_pred)
# Out:
# 0.7761607761607762

# %% [markdown]
# **Задача 4. Сравнение с древовидными моделями**
#
# Обучите модель случайного леса на тех же данных для предсказания `price_category`. Сравните качество с моделью логистической регрессии и многослойного персептрона. Словами опишите, какая из моделей в каких случаях работает лучше по результатам на тестовой выборке, обоснуйте свой выбор.

# %%
new_df = df.drop(columns=['odometer/price_std', 'price', 'id'])

x = new_df.drop(columns='price_category')
y = new_df.price_category

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
rfc = RandomForestClassifier(n_estimators=200, criterion='gini')
rfc.fit(x_train, y_train)
rfc_test_pred = rfc.predict(x_test)
accuracy_score(y_test, rfc_test_pred)
# Out:
# 0.7584892584892585

# %%
rfc.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 300,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Все модели работают плюс минус одинаково на одних и тех же данных, метрика качества слабо колеблется.

# %% [markdown]
# **Задача 5. Стратегия голосования**
#
# Реализуйте стратегию голосования для предсказания целевой переменной.
# Голосование в задаче классификации — это когда несколько моделей выдают свои предикты, и финальным выбирается тот предикт, который предсказали большинство моделей.
#
# Для реализации этой стратегии проделайте следующее:
#
# - сохраните предсказания каждой из моделей (случайный лес, многослойный персептрон, логистическая регрессия) для тестовой выборки в датафрейм `pred_df`;
# - в четвёртую колонку `target` положите тот класс, который предсказало большинство классификаторов; например, если в строке были значения `high, medium, medium`, в `target` нужно положить `medium`;
#
#      если в строке три разных класса (`high, medium, low`), придумайте свою стратегию по выбору значения; самая простая стратегия — выбрать рандомно одно значение из трёх;
#
# - посчитайте точность предсказания с помощью голосования; выведите значения метрик accuracy и confusion_matrix.
#
# Добейтесь значения точности > 78%.

# %%
n_df = pd.DataFrame(list(zip(rfc_test_pred, mlp_test_pred, logreg_pred2)), columns=['rfc', 'mlp', 'logreg'])
n_df['target'] = n_df.apply(lambda row: mode([row['rfc'], row['mlp'], row['logreg']]), axis=1)
n_df
# Out:
#          rfc     mlp  logreg  target
# 0       high    high    high    high
# 1     medium  medium  medium  medium
# 2        low     low     low     low
# 3        low     low     low     low
# 4       high    high    high    high
# ...      ...     ...     ...     ...
# 2881  medium  medium  medium  medium
# 2882     low  medium     low     low
# 2883     low     low     low     low
# 2884  medium  medium  medium  medium
# 2885     low     low     low     low
#
# [2886 rows x 4 columns]

# %%
accuracy_score(y_test, n_df.target)
# Out:
# 0.7837837837837838

# %% [markdown]
# **Примечание**
#
# В этой практической работе перед вами встал выбор: включать ли колонку `id`. При удалении данной колонки во время обучения логистической регрессии качество заметно улучшается.
#
# Обучать любую модель (будь то логистическая, линейная регрессия или древовидный алгоритм) на данных айдишников не считается хорошей практикой. Как правило, между `id` и целевой переменной не должно быть никаких взаимосвязей. Включая колонку `id` в качества атрибута в обучение, вы стараетесь подогнать результаты своей модели под айдишники записей. Таким образом модель обучится на некотором наборе частных случаев и, возможно, не обратит внимание на общие зависимости.
